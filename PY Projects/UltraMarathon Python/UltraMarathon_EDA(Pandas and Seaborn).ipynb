# %% [markdown]
# # Setting Up

# %%
# Importing libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading in the dataset file
df = pd.read_csv(r"Downloads\archive (15)\TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\ASAD\AppData\Local\Temp\ipykernel_37384\2400655657.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"Downloads\archive (15)\TWO_CENTURIES_OF_UM_RACES.csv")

# %%
# View the number of rows and columns
df.shape
# Out:
# (7461195, 13)

# %%
# Print the first 10 rows of the dataset
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
# Column datatypes
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Using USA, 50km or 50mi in 2020

# %%
# Selecting 50km and 50mi races

df[df["Event distance/length"].isin(["50km","50mi"])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# Filter the above dataframe to just 2020 races

df[(df["Event distance/length"].isin(["50km","50mi"])) & (df["Year of event"] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
# Filter the above dataframe to just USA races and bring all filters together

df[(df["Event distance/length"].isin(["50km","50mi"])) & (df["Year of event"] == 2020) & (df["Event name"].str.contains("USA"))]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
races = df[(df["Event distance/length"].isin(["50km","50mi"])) & (df["Year of event"] == 2020) & (df["Event name"].str.contains("USA"))]

# %%
races
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
# Remove (USA) from event name since all races in the df are in the US.
races["Event name"].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26524, dtype: object

# %%
races["Event name"] = races["Event name"].str.split('(').str.get(0)
# Out:
# C:\Users\ASAD\AppData\Local\Temp\ipykernel_37384\3776773333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   races["Event name"] = races["Event name"].str.split('(').str.get(0)

# %%
races.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
# Clean up athlete age

races["athlete_age"] = 2020 - races["Athlete year of birth"]
# Out:
# C:\Users\ASAD\AppData\Local\Temp\ipykernel_37384\2048557838.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   races["athlete_age"] = 2020 - races["Athlete year of birth"]

# %%
# Confirming the changes
races.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
# Remove "h" from Athlete performance
races["Athlete performance"] = races["Athlete performance"].str.split(" ").str.get(0)
# Out:
# C:\Users\ASAD\AppData\Local\Temp\ipykernel_37384\3590932543.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   races["Athlete performance"] = races["Athlete performance"].str.split(" ").str.get(0)

# %%
# Confirming the changes
races.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
# Drop columns: Athlete club, Athlete age category, Athlete year of birth

races = races.drop(['Athlete club', 'Athlete age category', 'Athlete year of birth'], axis=1)

# %%
# Confirming the changes
races.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
# Clean up null values
races.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete country                0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  235
# dtype: int64

# %%
races[races["athlete_age"].isna()]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# Dropping null values
races = races.dropna()

# %%
# Assessing the new number of rows and columns
races.shape
# Out:
# (26289, 11)

# %%
# Check for duplicates
races[races.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete country, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
races.reset_index(drop=True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 26284           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26285           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26286           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26287           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26288           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# Fix some of the datatypes

races.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete country               object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
# Converting ages to ints
races["athlete_age"] = races["athlete_age"].astype(int)

# %%
# Converting avergae speeds to float
races["Athlete average speed"] = races["Athlete average speed"].astype(float)

# %%
races.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete country               object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int32
# dtype: object

# %%
# Confirming changes
races.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
races.reset_index(inplace=True, drop=True)

# %%
races
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 26284           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26285           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26286           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26287           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26288           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
races.head()
# Out:
#    Year of event Event dates                                Event name  \
# 0           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#   Event distance/length  Event number of finishers Athlete performance  \
# 0                  50km                         20             3:17:55
# 1                  50km                         20             4:02:32
# 2                  50km                         20             4:07:57
# 3                  50km                         20             4:22:02
# 4                  50km                         20             4:27:34
#
#   Athlete country Athlete gender  Athlete average speed  Athlete ID  \
# ...

# %%
races.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete country               object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int32
# dtype: object

# %%
# Rename columns
#Year of event                  int64
#Event dates                   object
#Event name                    object
#Event distance/length         object
#Event number of finishers      int64
#Athlete performance           object
#Athlete country               object
#Athlete gender                object
#Athlete average speed        float64
#Athlete ID                     int64
#athlete_age                    int32

# %%
# Renaming columns for ease of writing queries
races = races.rename(columns = {'Year of event': 'year',
                       'Event dates': 'race_day',
                       'Event name': 'race_name',
                       'Event distance/length': 'race_length',
                       'Event number of finishers': 'race_number_of_finishers',
                       'Athlete performance': 'athlete_performance',
                       'Athlete country': 'athlete_country',
                       'Athlete gender': 'athlete_gender',
                       'Athlete average speed': 'athlete_average_speed',
                       'Athlete ID': 'athlete_id'   
})

# %%
races.head()
# Out:
#    year    race_day                                 race_name race_length  \
# 0  2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1  2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2  2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3  2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4  2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#    race_number_of_finishers athlete_performance athlete_country  \
# 0                        20             3:17:55             USA
# 1                        20             4:02:32             USA
# 2                        20             4:07:57             USA
# 3                        20             4:22:02             USA
# 4                        20             4:27:34             USA
#
#   athlete_gender  athlete_average_speed  athlete_id  athlete_age
# 0              M                 15.158       71287           29
# ...

# %% [markdown]
# # Data Visualisations - EDA part 1

# %% [markdown]
# ## Race Length Frequency

# %%
# Creating a histogram for race length frequency

sns.histplot(races["race_length"])
# Out:
# <AxesSubplot:xlabel='race_length', ylabel='Count'>

# %% [markdown]
# ## Gender participation in each race type

# %%
# Creating a histogram to highlight gender participation in each race type

sns.histplot(data=races, x='race_length', hue='athlete_gender')
# Out:
# <AxesSubplot:xlabel='race_length', ylabel='Count'>

# %% [markdown]
# ## Average Speeds in 50mi

# %%
# Extracting the necessary data
races_50mi = races[races["race_length"] == "50mi"]
races_50mi
# Out:
#        year    race_day                   race_name race_length  \
# 433    2020  01.02.2020  Elephant Mountain 50 Mile         50mi
# 434    2020  01.02.2020  Elephant Mountain 50 Mile         50mi
# 435    2020  01.02.2020  Elephant Mountain 50 Mile         50mi
# 436    2020  01.02.2020  Elephant Mountain 50 Mile         50mi
# 437    2020  01.02.2020  Elephant Mountain 50 Mile         50mi
# ...     ...         ...                         ...         ...
# 26045  2020  10.10.2020  Old Cascadia 50 Mile Race         50mi
# 26046  2020  10.10.2020  Old Cascadia 50 Mile Race         50mi
# 26047  2020  10.10.2020  Old Cascadia 50 Mile Race         50mi
# 26048  2020  10.10.2020  Old Cascadia 50 Mile Race         50mi
# 26049  2020  10.10.2020  Old Cascadia 50 Mile Race         50mi
#
#        race_number_of_finishers athlete_performance athlete_country  \
# 433                          10             8:51:11             USA
# ...

# %%
# Distplot for average speed in 50mi
sns.histplot(races_50mi["athlete_average_speed"])
# Out:
# <AxesSubplot:xlabel='athlete_average_speed', ylabel='Count'>

# %% [markdown]
# ## Average Speeds in 50km

# %%
# Querying for the necessary data
races_50km = races[races["race_length"] == "50km"]
races_50km
# Out:
#        year    race_day                                 race_name race_length  \
# 0      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# ...     ...         ...                                       ...         ...
# 26284  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26285  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26286  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26287  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26288  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
#
# ...

# %%
# Distplot for average speed in 50km
sns.histplot(races_50km["athlete_average_speed"])
# Out:
# <AxesSubplot:xlabel='athlete_average_speed', ylabel='Count'>

# %% [markdown]
# ## Average Speeds In Both Races For Each Gender

# %%
# Violin plot to show the distribution of average speeds for both genders
sns.violinplot(data=races, x='race_length', y='athlete_average_speed', hue='athlete_gender', split=True, inner='quart')
# Out:
# <AxesSubplot:xlabel='race_length', ylabel='athlete_average_speed'>

# %% [markdown]
# ## Relationship between athlete age and average speed

# %%
# Finding the relationship between athlete age and average speed
sns.lmplot(data=races, x='athlete_age', y='athlete_average_speed', hue='athlete_gender')

# %% [markdown]
# # More Exploratory Data Analysis(Interesting Questions)

# %%
#race_day
#race_name
#race_length
#race_number_of_finishers
#athlete_performance
#athlete_country
#athlete_gender
#athlete_average_speed

# %% [markdown]
# ## Difference in speed for 50km and 50mi, male to female

# %%
races.groupby(["race_length","athlete_gender"])["athlete_average_speed"].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 7.092015
#              M                 7.743376
# 50mi         F                 6.830764
#              M                 7.249766
# Name: athlete_average_speed, dtype: float64

# %% [markdown]
# ## What age runs 50mi the best(20+ minimium race count)

# %%
races.query('race_length == "50mi"').groupby("athlete_age")["athlete_average_speed"].agg(['mean','count']).sort_values('mean', ascending=False).query('count > 19')
# Out:
#                  mean  count
# athlete_age
# 29           7.895574    136
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.471053     95
# 31           7.440842    139
# 38           7.420884    232
# 35           7.414633    196
# 36           7.394645    186
# 33           7.379188    149
# 22           7.367902     41
# 26           7.328584     77
# 42           7.327656    209
# 24           7.327203     74
# 34           7.307923    183
# 21           7.304658     38
# 40           7.304553    237
# 20           7.293778     27
# 39           7.283566    228
# 32           7.269518    164
# 37           7.220493    221
# 27           7.201748    119
# 41           7.185767    180
# 45           7.130667    156
# 47           7.085410    156
# 44           7.047361    180
# 51           7.014248    125
# 46           6.900326    175
# 43           6.874670    188
# 52           6.847400    130
# ...

# %% [markdown]
# ## What age runs 50mi worse

# %%
races.query('race_length == "50mi"').groupby("athlete_age")["athlete_average_speed"].agg(['mean','count']).sort_values('mean', ascending=True).query('count > 19')
# Out:
#                  mean  count
# athlete_age
# 60           6.227206     34
# 62           6.267564     39
# 61           6.358355     31
# 63           6.514806     31
# 58           6.582328     67
# 64           6.620727     22
# 50           6.671541    172
# 59           6.672072     83
# 48           6.696853    136
# 56           6.708373     67
# 53           6.724598     97
# 57           6.783205     78
# 49           6.789776    161
# 54           6.792429     84
# 55           6.814800     70
# 52           6.847400    130
# 43           6.874670    188
# 46           6.900326    175
# 51           7.014248    125
# 44           7.047361    180
# 47           7.085410    156
# 45           7.130667    156
# 41           7.185767    180
# 27           7.201748    119
# 37           7.220493    221
# 32           7.269518    164
# 39           7.283566    228
# 20           7.293778     27
# 40           7.304553    237
# 21           7.304658     38
# ...

# %% [markdown]
# ## Seasons for the data - Are athletes slower in summer than in winter?

# %%
# spring 3-5
# summer 6-8
# fall 9-11
# winter 12-2

# %%
# Creating race month column
races["race_month"] = races["race_day"].str.split('.').str.get(1).astype(int)

# %%
races
# Out:
#        year    race_day                                 race_name race_length  \
# 0      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# ...     ...         ...                                       ...         ...
# 26284  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26285  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26286  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26287  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26288  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
#
# ...

# %%
# Creating race season column
def season_cat(row):
    spring = [3,4,5]
    summer = [6,7,8]
    fall = [9,10,11]
    winter = [12,1,2]
    if row["race_month"] in winter:
        return 'Winter'
    elif row["race_month"] in spring:
        return 'Spring'
    elif row["race_month"] in summer:
        return 'Summer'
    elif row["race_month"] in fall:
        return 'Fall'
    else:
        return "No season"
    
races["race_season"] = races.apply(season_cat, axis='columns')

races
# Out:
#        year    race_day                                 race_name race_length  \
# 0      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4      2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# ...     ...         ...                                       ...         ...
# 26284  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26285  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26286  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26287  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26288  2020  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
#
# ...

# %%
# Querying for the data
races.groupby("race_season")["athlete_average_speed"].mean()
# Out:
# race_season
# Fall         7.406619
# No season    6.756400
# Spring       7.703542
# Summer       6.859274
# Winter       7.614325
# Name: athlete_average_speed, dtype: float64

# %%
# By gender
races.groupby(["race_season","athlete_gender"])["athlete_average_speed"].mean()
# Out:
# race_season  athlete_gender
# Fall         F                 7.050348
#              M                 7.572631
# No season    F                 6.413917
#              M                 6.956803
# Spring       F                 7.268203
#              M                 7.926953
# Summer       F                 6.627858
#              M                 6.973046
# Winter       F                 7.159963
#              M                 7.824557
# Name: athlete_average_speed, dtype: float64
